# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
lengths = [20,50,100,200]
Temp = [0.5,1.0,1.5,2.0]

# %%
lengths = [200]
Temp = [0.5,1.0,1.5,2.0]
for T in Temp:
  for N in lengths:
    rdf = np.loadtxt(f"/bsuhome/stephaniemccallu/scratch/mse563/LAMMPS-Polymers-Fene/slurm-batch-scripts/N{N}T{T}-T{T}.rdf",skiprows=4)
    plt.plot(rdf[:,1],rdf[:,2],label=f"N:{N} T:{T}")
plt.legend()
plt.title("Rdf of 200-mers with Fene bonds")
# Out:
# Text(0.5, 1.0, 'Rdf of 200-mers with Fene bonds')

# %%
lengths = [20,50,100,200]
Temp = [1.0]
for T in Temp:
  for N in lengths:
    rdf = np.loadtxt(f"/bsuhome/stephaniemccallu/scratch/mse563/LAMMPS-Polymers-Fene/slurm-batch-scripts/N{N}T{T}-T{T}.rdf",skiprows=4)
    plt.plot(rdf[:,1],rdf[:,2],label=f"N:{N} T:{T}")
plt.legend()
plt.title("Rdf of N-mers with Fene bonds at 1.0T")
# Out:
# Text(0.5, 1.0, 'Rdf of N-mers with Fene bonds at 1.0T')

# %%
Temp = [0.5]
for T in Temp:
  for N in lengths:
    rg = np.loadtxt(f"/bsuhome/stephaniemccallu/scratch/mse563/LAMMPS-Polymers-Fene/slurm-batch-scripts/rg_N{N}T{T}.dat",skiprows=2)
    rg_avg = np.mean(rg[500:1000,1])
    print(rg_avg)
    plt.plot(N,rg_avg,label=f"N:{N} T:{T}", marker ='*')
plt.legend(loc='right')
plt.title("N vs. Radius of Gyration")
# Out:
# 2.23090778
# 4.1605257
# 8.70071718
# 2.77075412
# Text(0.5, 1.0, 'N vs. Radius of Gyration')

# %%
Temp = [2.0]
for T in Temp:
  for N in lengths:
    msd = np.loadtxt(f"/bsuhome/stephaniemccallu/scratch/mse563/LAMMPS-Polymers-Fene/slurm-batch-scripts/msd_N{N}T{T}.dat",skiprows=2)
    plt.plot(msd[:200,0],msd[:200,1],label=f"N:{N} T:{T}")
plt.legend(loc='center left')
plt.xscale('log')
plt.yscale('log')
plt.title("MSD at 2.0T")
# Out:
# Text(0.5, 1.0, 'MSD at 2.0T')

# %%
for T in Temp:
  for N in lengths:
    thermo = np.loadtxt(f"/bsuhome/stephaniemccallu/scratch/mse563/LAMMPS-Polymers-Fene/slurm-batch-scripts/N{N}T{T}-T{T}-thermo.txt",skiprows=2)
    plt.plot(thermo[:1000,0],thermo[:1000,1],label=f"N:{N} T:{T}")
plt.legend(loc='right')
plt.title("PE")
# Out:
# Text(0.5, 1.0, 'PE')

# %%
for T in Temp:
  for N in lengths:
    thermo = np.loadtxt(f"/bsuhome/stephaniemccallu/scratch/mse563/LAMMPS-Polymers-Fene/slurm-batch-scripts/N{N}T{T}-T{T}-thermo.txt",skiprows=2)
    plt.plot(thermo[:1000,0],thermo[:1000,2],label=f"N:{N} T:{T}")
plt.legend()
plt.title("KE")
# Out:
# Text(0.5, 1.0, 'KE')

# %%
for T in Temp:
  for N in lengths:
    thermo = np.loadtxt(f"/bsuhome/stephaniemccallu/scratch/mse563/LAMMPS-Polymers-Fene/slurm-batch-scripts/N{N}T{T}-T{T}-thermo.txt",skiprows=2)
    plt.plot(thermo[:1000,0],thermo[:1000,2],label=f"N:{N} T:{T}")
plt.legend()
plt.title("TE")
# Out:
# Text(0.5, 1.0, 'TE')

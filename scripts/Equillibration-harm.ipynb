# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
lengths = [20,50,100,200]
Temp = [0.5,1.0,1.5,2.0]

# %%
def autocorr1D(array):
    """Takes in a linear np array, performs autocorrelation
    function and returns normalized array with half the length
    of the input.

    Parameters
    ----------
    data : numpy.typing.Arraylike, required
        1-D series of data to perform autocorrelation on.

    Returns
    -------
    1D np.array

    """
    ft = np.fft.rfft(array - np.average(array))
    acorr = np.fft.irfft(ft * np.conjugate(ft)) / (len(array) * np.var(array))
    return acorr[0 : len(acorr) // 2]  # noqa: E203

# %%
def decorrelation_time(ac,total_steps):
    decorrelation_time = np.where(ac <= 0)[0][0]
    ind_samples = (total_steps/10)/decorrelation_time
    print("decorrelation time: ",decorrelation_time, ", independent samples: ", ind_samples)
    return

# %%
lengths = [20]
Temp = [0.5,1.0,1.5,2.0]
for T in Temp:
  for N in lengths:
    thermo = np.loadtxt(f"/bsuhome/stephaniemccallu/scratch/mse563/LAMMPS-Polymers/slurm-batch-scripts/N{N}T{T}-T{T}-thermo.txt",skiprows=2)
    plt.plot(thermo[:,0],thermo[:,1],label=f"N:{N} T:{T}")
    ac = autocorr1D(thermo[:,1])
    print(thermo[-1,0])
    decorrelation_time(ac,thermo[-1,0])
plt.legend()
plt.title("PE")
# Out:
# 1000000.0
# decorrelation time:  177 , independent samples:  564.9717514124294
# 1000000.0
# decorrelation time:  13 , independent samples:  7692.307692307692
# 1000000.0
# decorrelation time:  19 , independent samples:  5263.1578947368425
# 1000000.0
# decorrelation time:  2 , independent samples:  50000.0
# Text(0.5, 1.0, 'PE')

# %%
lengths = [50]
Temp = [0.5,1.0,1.5,2.0]
for T in Temp:
  for N in lengths:
    thermo = np.loadtxt(f"/bsuhome/stephaniemccallu/scratch/mse563/LAMMPS-Polymers/slurm-batch-scripts/N{N}T{T}-T{T}-thermo.txt",skiprows=2)
    plt.plot(thermo[:,0],thermo[:,1],label=f"N:{N} T:{T}")
    ac = autocorr1D(thermo[:,1])
    print(thermo[-1,0])
    decorrelation_time(ac,thermo[-1,0])
plt.legend()
plt.title("PE")
# Out:
# 1000000.0
# decorrelation time:  100 , independent samples:  1000.0
# 1000000.0
# decorrelation time:  11 , independent samples:  9090.90909090909
# 1000000.0
# decorrelation time:  6 , independent samples:  16666.666666666668
# 1000000.0
# decorrelation time:  7 , independent samples:  14285.714285714286
# Text(0.5, 1.0, 'PE')

# %%
lengths = [100]
Temp = [0.5,1.0,1.5,2.0]
for T in Temp:
  for N in lengths:
    thermo = np.loadtxt(f"/bsuhome/stephaniemccallu/scratch/mse563/LAMMPS-Polymers/slurm-batch-scripts/N{N}T{T}-T{T}-thermo.txt",skiprows=2)
    plt.plot(thermo[:,0],thermo[:,1],label=f"N:{N} T:{T}")
    ac = autocorr1D(thermo[:,1])
    print(thermo[-1,0])
    decorrelation_time(ac,thermo[-1,0])
plt.legend()
plt.title("PE")
# Out:
# 10000000.0
# decorrelation time:  1977 , independent samples:  505.8168942842691
# 3039000.0
# decorrelation time:  53 , independent samples:  5733.962264150943
# 10000000.0
# decorrelation time:  17 , independent samples:  58823.529411764706
# 10000000.0
# decorrelation time:  54 , independent samples:  18518.51851851852
# Text(0.5, 1.0, 'PE')

# %%
lengths = [200]
Temp = [1.0,1.5,2.0]
for T in Temp:
  for N in lengths:
    thermo = np.loadtxt(f"/bsuhome/stephaniemccallu/scratch/mse563/LAMMPS-Polymers/slurm-batch-scripts/N{N}T{T}-T{T}-thermo.txt",skiprows=2)
    plt.plot(thermo[:,0],thermo[:,1],label=f"N:{N} T:{T}")
    ac = autocorr1D(thermo[:,1])
    print(thermo[-1,0])
    decorrelation_time(ac,thermo[-1,0])
plt.legend()
plt.title("PE")
# Out:
# 100000.0
# decorrelation time:  21 , independent samples:  476.1904761904762
# 100000.0
# decorrelation time:  19 , independent samples:  526.3157894736842
# 100000.0
# decorrelation time:  14 , independent samples:  714.2857142857143
# Text(0.5, 1.0, 'PE')

# %%
lengths = [200]
Temp = [0.5]
for T in Temp:
  for N in lengths:
    thermo = np.loadtxt(f"/bsuhome/stephaniemccallu/scratch/mse563/LAMMPS-Polymers/slurm-batch-scripts/N{N}T{T}-T{T}-thermo.txt",skiprows=2)
    plt.plot(thermo[:,0],thermo[:,1],label=f"N:{N} T:{T}")
    ac = autocorr1D(thermo[:,1])
    print(thermo[-1,0])
    decorrelation_time(ac,thermo[-1,0])
plt.legend()
plt.title("PE")
# Out:
# 8546000.0
# decorrelation time:  1730 , independent samples:  493.9884393063584
# Text(0.5, 1.0, 'PE')
